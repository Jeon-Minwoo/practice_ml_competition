# %% [markdown]
# 2022_봄학기_실전기계학습_Competition Guide Code
#
# 1. Pretraioned Model 사용금지
# 2. Personal Data 사용금지
# 3. Epoch 50회까지 제한
# 4. Test Data로 Train 금지
# 5. Model Param 5M이상 금지
# 6. 최종 제출 모델 파일로 조교가 재현시 비슷한 성능이 나오지 않은 경우
# Cheating으로 간주
# 7. 기타 궁금한 사항들(간단하거나 쉬운 것도 괜찮습니다)은 조교에게 질문주셔요
# - Email
# - 전자정보대학 325-1 방문

# %% [markdown]
# 아래 코드는 각종 Library를 선언하는 부분입니다.

# %%
# importing all the libraries we need
import numpy as np
import matplotlib.pyplot as plt
import sys
import os
import time
import random 
import pandas as pd
import torch
from torch import nn, cuda, optim
from torchvision import models,transforms,datasets
from torch.utils.data import DataLoader,random_split
from PIL import Image
import seaborn as sns
import torch.nn.functional as F

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mkdir ./dataset
# !unzip /content/drive/MyDrive/Bird.zip -d ./dataset
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   inflating: ./dataset/train/TASMANIAN HEN/108.jpg
#   inflating: ./dataset/train/TASMANIAN HEN/109.jpg
#   inflating: ./dataset/train/TASMANIAN HEN/110.jpg
#   inflating: ./dataset/train/TASMANIAN HEN/111.jpg
#   inflating: ./dataset/train/TASMANIAN HEN/112.jpg
#   inflating: ./dataset/train/TASMANIAN HEN/113.jpg
#   inflating: ./dataset/train/TASMANIAN HEN/114.jpg
#   inflating: ./dataset/train/TASMANIAN HEN/115.jpg
#   inflating: ./dataset/train/TASMANIAN HEN/116.jpg
#   inflating: ./dataset/train/TASMANIAN HEN/117.jpg
#   inflating: ./dataset/train/TASMANIAN HEN/118.jpg
#   inflating: ./dataset/train/TASMANIAN HEN/119.jpg
#   inflating: ./dataset/train/TASMANIAN HEN/120.jpg
#   inflating: ./dataset/train/TASMANIAN HEN/121.jpg
#   inflating: ./dataset/train/TASMANIAN HEN/122.jpg
#   inflating: ./dataset/train/TASMANIAN HEN/123.jpg
#   inflating: ./dataset/train/TASMANIAN HEN/124.jpg
#   inflating: ./dataset/train/TASMANIAN HEN/125.jpg
#   inflating: ./dataset/train/TASMANIAN HEN/126.jpg
#   inflating: ./dataset/train/TASMANIAN HEN/127.jpg
#   inflating: ./dataset/train/TASMANIAN HEN/128.jpg
#   inflating: ./dataset/train/TASMANIAN HEN/129.jpg
#   inflating: ./dataset/train/TASMANIAN HEN/130.jpg
#   inflating: ./dataset/train/TASMANIAN HEN/131.jpg
#   inflating: ./dataset/train/TASMANIAN HEN/132.jpg
#   inflating: ./dataset/train/TASMANIAN HEN/133.jpg
#   inflating: ./dataset/train/TASMANIAN HEN/134.jpg
#   inflating: ./dataset/train/TASMANIAN HEN/135.jpg
#    creating: ./dataset/train/TEAL DUCK/
#   inflating: ./dataset/train/TEAL DUCK/001.jpg
#   inflating: ./dataset/train/TEAL DUCK/002.jpg
#   inflating: ./dataset/train/TEAL DUCK/003.jpg
#   inflating: ./dataset/train/TEAL DUCK/004.jpg
#   inflating: ./dataset/train/TEAL DUCK/005.jpg
#   inflating: ./dataset/train/TEAL DUCK/006.jpg
#   inflating: ./dataset/train/TEAL DUCK/007.jpg
#   inflating: ./dataset/train/TEAL DUCK/008.jpg
#   inflating: ./dataset/train/TEAL DUCK/009.jpg
#   inflating: ./dataset/train/TEAL DUCK/010.jpg
#   inflating: ./dataset/train/TEAL DUCK/011.jpg
#   inflating: ./dataset/train/TEAL DUCK/012.jpg
#   inflating: ./dataset/train/TEAL DUCK/013.jpg
#   inflating: ./dataset/train/TEAL DUCK/014.jpg
#   inflating: ./dataset/train/TEAL DUCK/015.jpg
#   inflating: ./dataset/train/TEAL DUCK/016.jpg
#   inflating: ./dataset/train/TEAL DUCK/017.jpg
#   inflating: ./dataset/train/TEAL DUCK/018.jpg
#   inflating: ./dataset/train/TEAL DUCK/019.jpg
#   inflating: ./dataset/train/TEAL DUCK/020.jpg
#   inflating: ./dataset/train/TEAL DUCK/021.jpg
#   inflating: ./dataset/train/TEAL DUCK/022.jpg
#   inflating: ./dataset/train/TEAL DUCK/023.jpg
#   inflating: ./dataset/train/TEAL DUCK/024.jpg
#   inflating: ./dataset/train/TEAL DUCK/025.jpg
#   inflating: ./dataset/train/TEAL DUCK/026.jpg
#   inflating: ./dataset/train/TEAL DUCK/027.jpg
#   inflating: ./dataset/train/TEAL DUCK/028.jpg
#   inflating: ./dataset/train/TEAL DUCK/029.jpg
#   inflating: ./dataset/train/TEAL DUCK/030.jpg
#   inflating: ./dataset/train/TEAL DUCK/031.jpg
#   inflating: ./dataset/train/TEAL DUCK/032.jpg
jpg
#   inflating: ./dataset/train/YELLOW CACIQUE/110.jpg
#   inflating: ./dataset/train/YELLOW CACIQUE/111.jpg
#   inflating: ./dataset/train/YELLOW CACIQUE/112.jpg
#   inflating: ./dataset/train/YELLOW CACIQUE/113.jpg
#   inflating: ./dataset/train/YELLOW CACIQUE/114.jpg
#   inflating: ./dataset/train/YELLOW CACIQUE/115.jpg
#   inflating: ./dataset/train/YELLOW CACIQUE/116.jpg
#   inflating: ./dataset/train/YELLOW CACIQUE/117.jpg
#   inflating: ./dataset/train/YELLOW CACIQUE/118.jpg
#   inflating: ./dataset/train/YELLOW CACIQUE/119.jpg
#   inflating: ./dataset/train/YELLOW CACIQUE/120.jpg
#   inflating: ./dataset/train/YELLOW CACIQUE/121.jpg
#   inflating: ./dataset/train/YELLOW CACIQUE/122.jpg
#   inflating: ./dataset/train/YELLOW CACIQUE/123.jpg
#   inflating: ./dataset/train/YELLOW CACIQUE/124.jpg
#   inflating: ./dataset/train/YELLOW CACIQUE/125.jpg
#   inflating: ./dataset/train/YELLOW CACIQUE/126.jpg
#   inflating: ./dataset/train/YELLOW CACIQUE/127.jpg
#   inflating: ./dataset/train/YELLOW CACIQUE/128.jpg
#   inflating: ./dataset/train/YELLOW CACIQUE/129.jpg
#   inflating: ./dataset/train/YELLOW CACIQUE/130.jpg
#   inflating: ./dataset/train/YELLOW CACIQUE/131.jpg
#   inflating: ./dataset/train/YELLOW CACIQUE/132.jpg
#   inflating: ./dataset/train/YELLOW CACIQUE/133.jpg
#   inflating: ./dataset/train/YELLOW CACIQUE/134.jpg
#   inflating: ./dataset/train/YELLOW CACIQUE/135.jpg
#   inflating: ./dataset/train/YELLOW CACIQUE/136.jpg
#   inflating: ./dataset/train/YELLOW CACIQUE/137.jpg
#   inflating: ./dataset/train/YELLOW CACIQUE/138.jpg
#   inflating: ./dataset/train/YELLOW CACIQUE/139.jpg
#   inflating: ./dataset/train/YELLOW CACIQUE/140.jpg
#   inflating: ./dataset/train/YELLOW CACIQUE/141.jpg
#   inflating: ./dataset/train/YELLOW CACIQUE/142.jpg
#   inflating: ./dataset/train/YELLOW CACIQUE/143.jpg
#   inflating: ./dataset/train/YELLOW CACIQUE/144.jpg
#   inflating: ./dataset/train/YELLOW CACIQUE/145.jpg
#   inflating: ./dataset/train/YELLOW CACIQUE/146.jpg
#   inflating: ./dataset/train/YELLOW CACIQUE/147.jpg
#   inflating: ./dataset/train/YELLOW CACIQUE/148.jpg
#   inflating: ./dataset/train/YELLOW CACIQUE/149.jpg
#   inflating: ./dataset/train/YELLOW CACIQUE/150.jpg
#   inflating: ./dataset/train/YELLOW CACIQUE/151.jpg
#   inflating: ./dataset/train/YELLOW CACIQUE/152.jpg
#   inflating: ./dataset/train/YELLOW CACIQUE/153.jpg
#   inflating: ./dataset/train/YELLOW CACIQUE/154.jpg
#   inflating: ./dataset/train/YELLOW CACIQUE/155.jpg
#    creating: ./dataset/train/YELLOW HEADED BLACKBIRD/
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/001.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/002.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/003.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/004.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/005.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/006.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/007.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/008.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/009.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/010.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/011.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/012.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/013.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/014.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/015.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/016.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/017.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/018.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/019.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/020.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/021.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/022.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/023.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/024.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/025.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/026.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/027.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/028.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/029.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/030.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/031.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/032.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/033.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/034.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/035.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/036.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/037.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/038.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/039.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/040.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/041.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/042.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/043.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/044.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/045.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/046.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/047.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/048.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/049.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/050.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/051.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/052.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/053.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/054.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/055.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/056.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/057.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/058.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/059.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/060.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/061.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/062.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/063.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/064.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/065.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/066.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/067.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/068.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/069.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/070.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/071.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/072.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/073.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/074.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/075.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/076.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/077.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/078.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/079.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/080.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/081.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/082.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/083.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/084.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/085.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/086.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/087.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/088.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/089.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/090.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/091.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/092.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/093.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/094.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/095.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/096.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/097.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/098.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/099.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/100.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/101.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/102.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/103.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/104.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/105.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/106.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/107.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/108.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/109.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/110.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/111.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/112.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/113.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/114.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/115.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/116.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/117.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/118.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/119.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/120.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/121.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/122.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/123.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/124.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/125.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/126.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/127.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/128.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/129.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/130.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/131.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/132.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/133.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/134.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/135.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/136.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/137.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/138.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/139.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/140.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/141.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/142.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/143.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/144.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/145.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/146.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/147.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/148.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/149.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/150.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/151.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/152.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/153.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/154.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/155.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/156.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/157.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/158.jpg
#   inflating: ./dataset/train/YELLOW HEADED BLACKBIRD/159.jpg

# %% [markdown]
# Google Drive와 연동하기 위한 코드입니다
# 아래 코드를 실행하면 이메일 계정 확인을 하게 되는데 모두 "수락"을 눌러주면됩니다

# %% [markdown]
# 업로드한 Dataset을 갖고와서 압축을 풀어주는 역할을 합니다

# %% [markdown]
# 불러온 데이터셋의 Class 별 사진 갯수를 보기 위한 코드입니다
# 각 Birds의 Class마다 대략 120~170여장의 사진이 있음을 확인할 수 있습니다.

# %%
# Knowing the data 
# data_dir = '/kaggle/input/100-bird-species/175/'
data_dir = '/content/dataset/train'

classes = []
img_per_class = []
os.rename(src="/content/dataset/train/BLACK & YELLOW  BROADBILL",dst="/content/dataset/train/BLACK & YELLOW BROADBILL")
# for folder in os.listdir(data_dir+'consolidated'):/
for folder in os.listdir(data_dir):    
    classes.append(folder)
    img_per_class.append(len(os.listdir(f'{data_dir}/{folder}')))
num_classes = len(classes)
df = pd.DataFrame({'Classes':classes, 'Examples':img_per_class})
df
# Out:
#                        Classes  Examples
# 0               INDIAN BUSTARD       131
# 1            CLARKS NUTCRACKER       161
# 2            SWINHOES PHEASANT       217
# 3    RUBY THROATED HUMMINGBIRD       135
# 4              CALIFORNIA GULL       120
# ..                         ...       ...
# 395        RED WISKERED BULBUL       123
# 396             BROWN THRASHER       165
# 397         AMERICAN GOLDFINCH       133
# 398            CHUCAO TAPACULO       141
# 399            CINNAMON ATTILA       124
#
# [400 rows x 2 columns]

# %% [markdown]
# 불러온 데이터의 클래스별로 랜덤하게 데이터를 한장씩 보는 역할을 하는 코드입니다.
# 추후 삭제해도 무방한 부분입니다

# %% [markdown]
# Train 시 로그를 보여주기위해 선언한 Class입니다.

# %%
class AverageMeter(object):
    r"""Computes and stores the average and current value
    """
    def __init__(self, name, fmt=':f'):
        self.name = name
        self.fmt = fmt
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

    def __str__(self):
        fmtstr = '{name} {val' + self.fmt + '} ({avg' + self.fmt + '})'
        return fmtstr.format(**self.__dict__)


class ProgressMeter(object):
    def __init__(self, num_batches, *meters, prefix=""):
        self.batch_fmtstr = self._get_batch_fmtstr(num_batches)
        self.meters = meters
        self.prefix = prefix

    def print(self, batch):
        entries = [self.prefix + self.batch_fmtstr.format(batch)]
        entries += [str(meter) for meter in self.meters]
        print('\t'.join(entries))

    def _get_batch_fmtstr(self, num_batches):
        num_digits = len(str(num_batches // 1))
        fmt = '{:' + str(num_digits) + 'd}'
        return '[' + fmt + '/' + fmt.format(num_batches) + ']'


def accuracy(output, target, topk=(1,)):
    r"""Computes the accuracy over the $k$ top predictions for the specified values of k
    """
    with torch.no_grad():
        maxk = max(topk)
        batch_size = target.size(0)

        # _, pred = output.topk(maxk, 1, True, True)
        # pred = pred.t()
        # correct = pred.eq(target.view(1, -1).expand_as(pred))

        # faster topk (ref: https://github.com/pytorch/pytorch/issues/22812)
        _, idx = output.sort(descending=True)
        pred = idx[:,:maxk]
        pred = pred.t()
        correct = pred.eq(target.view(1, -1).expand_as(pred))

        res = []
        for k in topk:
            correct_k = correct[:k].reshape(-1).float().sum(0, keepdim=True)
            res.append(correct_k.mul_(100.0 / batch_size))
        return res

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable

import math

class Swish(nn.Module):
    def __init__(self):
        super(Swish, self).__init__()

        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        return x * self.sigmoid(x)

NON_LINEARITY = {
    'ReLU': nn.ReLU(inplace=True),
    'Swish': Swish(),
}

def _RoundChannels(c, divisor=8, min_value=None):
    if min_value is None:
        min_value = divisor
    new_c = max(min_value, int(c + divisor / 2) // divisor * divisor)
    if new_c < 0.9 * c:
        new_c += divisor
    return new_c

def _SplitChannels(channels, num_groups):
    split_channels = [channels//num_groups for _ in range(num_groups)]
    split_channels[0] += channels - sum(split_channels)
    return split_channels

def Conv3x3Bn(in_channels, out_channels, stride, non_linear='ReLU'):
    return nn.Sequential(
        nn.Conv2d(in_channels, out_channels, 3, stride, 1, bias=False),
        nn.BatchNorm2d(out_channels),
        NON_LINEARITY[non_linear]
    )

def Conv1x1Bn(in_channels, out_channels, non_linear='ReLU'):
    return nn.Sequential(
        nn.Conv2d(in_channels, out_channels, 1, 1, 0, bias=False),
        nn.BatchNorm2d(out_channels),
        NON_LINEARITY[non_linear]
    )

class SqueezeAndExcite(nn.Module):
    def __init__(self, channels, squeeze_channels, se_ratio):
        super(SqueezeAndExcite, self).__init__()

        squeeze_channels = squeeze_channels * se_ratio
        if not squeeze_channels.is_integer():
            raise ValueError('channels must be divisible by 1/ratio')

        squeeze_channels = int(squeeze_channels)
        self.se_reduce = nn.Conv2d(channels, squeeze_channels, 1, 1, 0, bias=True)
        self.non_linear1 = NON_LINEARITY['Swish']
        self.se_expand = nn.Conv2d(squeeze_channels, channels, 1, 1, 0, bias=True)
        self.non_linear2 = nn.Sigmoid()

    def forward(self, x):
        y = torch.mean(x, (2, 3), keepdim=True)
        y = self.non_linear1(self.se_reduce(y))
        y = self.non_linear2(self.se_expand(y))
        y = x * y

        return y

class GroupedConv2d(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size, stride=1, padding=0):
        super(GroupedConv2d, self).__init__()

        self.num_groups = len(kernel_size)
        self.split_in_channels = _SplitChannels(in_channels, self.num_groups)
        self.split_out_channels = _SplitChannels(out_channels, self.num_groups)

        self.grouped_conv = nn.ModuleList()
        for i in range(self.num_groups):
            self.grouped_conv.append(nn.Conv2d(
                self.split_in_channels[i],
                self.split_out_channels[i],
                kernel_size[i],
                stride=stride,
                padding=padding,
                bias=False
            ))

    def forward(self, x):
        if self.num_groups == 1:
            return self.grouped_conv[0](x)

        x_split = torch.split(x, self.split_in_channels, dim=1)
        x = [conv(t) for conv, t in zip(self.grouped_conv, x_split)]
        x = torch.cat(x, dim=1)

        return x

class MDConv(nn.Module):
    def __init__(self, channels, kernel_size, stride):
        super(MDConv, self).__init__()

        self.num_groups = len(kernel_size)
        self.split_channels = _SplitChannels(channels, self.num_groups)

        self.mixed_depthwise_conv = nn.ModuleList()
        for i in range(self.num_groups):
            self.mixed_depthwise_conv.append(nn.Conv2d(
                self.split_channels[i],
                self.split_channels[i],
                kernel_size[i],
                stride=stride,
                padding=kernel_size[i]//2,
                groups=self.split_channels[i],
                bias=False
            ))

    def forward(self, x):
        if self.num_groups == 1:
            return self.mixed_depthwise_conv[0](x)

        x_split = torch.split(x, self.split_channels, dim=1)
        x = [conv(t) for conv, t in zip(self.mixed_depthwise_conv, x_split)]
        x = torch.cat(x, dim=1)

        return x

class MixNetBlock(nn.Module):
    def __init__(
        self,
        in_channels,
        out_channels,
        kernel_size=[3],
        expand_ksize=[1],
        project_ksize=[1],
        stride=1,
        expand_ratio=1,
        non_linear='ReLU',
        se_ratio=0.0
    ):

        super(MixNetBlock, self).__init__()

        expand = (expand_ratio != 1)
        expand_channels = in_channels * expand_ratio
        se = (se_ratio != 0.0)
        self.residual_connection = (stride == 1 and in_channels == out_channels)

        conv = []

        if expand:
            # expansion phase
            pw_expansion = nn.Sequential(
                GroupedConv2d(in_channels, expand_channels, expand_ksize),
                nn.BatchNorm2d(expand_channels),
                NON_LINEARITY[non_linear]
            )
            conv.append(pw_expansion)

        # depthwise convolution phase
        dw = nn.Sequential(
            MDConv(expand_channels, kernel_size, stride),
            nn.BatchNorm2d(expand_channels),
            NON_LINEARITY[non_linear]
        )
        conv.append(dw)

        if se:
            # squeeze and excite
            squeeze_excite = SqueezeAndExcite(expand_channels, in_channels, se_ratio)
            conv.append(squeeze_excite)

        # projection phase
        pw_projection = nn.Sequential(
            GroupedConv2d(expand_channels, out_channels, project_ksize),
            nn.BatchNorm2d(out_channels)
        )
        conv.append(pw_projection)

        self.conv = nn.Sequential(*conv)

    def forward(self, x):
        if self.residual_connection:
            return x + self.conv(x)
        else:
            return self.conv(x)

class MixNet(nn.Module):
    # [in_channels, out_channels, kernel_size, expand_ksize, project_ksize, stride, expand_ratio, non_linear, se_ratio]
    mixnet_s = [(16,  16,  [3],              [1],    [1],    1, 1, 'ReLU',  0.0),
                (16,  24,  [3],              [1, 1], [1, 1], 2, 6, 'ReLU',  0.0),
                (24,  24,  [3],              [1, 1], [1, 1], 1, 3, 'ReLU',  0.0),
                (24,  40,  [3, 5, 7],        [1],    [1],    2, 6, 'Swish', 0.5),
                (40,  40,  [3, 5],           [1, 1], [1, 1], 1, 6, 'Swish', 0.5),
                (40,  40,  [3, 5],           [1, 1], [1, 1], 1, 6, 'Swish', 0.5),
                (40,  40,  [3, 5],           [1, 1], [1, 1], 1, 6, 'Swish', 0.5),
                (40,  80,  [3, 5, 7],        [1],    [1, 1], 2, 6, 'Swish', 0.25),
                (80,  80,  [3, 5],           [1],    [1, 1], 1, 6, 'Swish', 0.25),
                (80,  80,  [3, 5],           [1],    [1, 1], 1, 6, 'Swish', 0.25),
                (80,  120, [3, 5, 7],        [1, 1], [1, 1], 1, 6, 'Swish', 0.5),
                (120, 120, [3, 5, 7, 9],     [1, 1], [1, 1], 1, 3, 'Swish', 0.5),
                (120, 120, [3, 5, 7, 9],     [1, 1], [1, 1], 1, 3, 'Swish', 0.5),
                (120, 200, [3, 5, 7, 9, 11], [1],    [1],    2, 6, 'Swish', 0.5),
                (200, 200, [3, 5, 7, 9],     [1],    [1, 1], 1, 6, 'Swish', 0.5),
                (200, 200, [3, 5, 7, 9],     [1],    [1, 1], 1, 6, 'Swish', 0.5)]
    
    mixnet_m = [(24,  24,  [3],          [1],    [1],    1, 1, 'ReLU',  0.0),
                (24,  32,  [3, 5, 7],    [1, 1], [1, 1], 2, 6, 'ReLU',  0.0),
                (32,  32,  [3],          [1, 1], [1, 1], 1, 3, 'ReLU',  0.0),
                (32,  40,  [3, 5, 7, 9], [1],    [1],    2, 6, 'Swish', 0.5),
                (40,  40,  [3, 5],       [1, 1], [1, 1], 1, 6, 'Swish', 0.5),
                (40,  40,  [3, 5],       [1, 1], [1, 1], 1, 6, 'Swish', 0.5),
                (40,  40,  [3, 5],       [1, 1], [1, 1], 1, 6, 'Swish', 0.5),
                (40,  80,  [3, 5, 7],    [1],    [1],    2, 6, 'Swish', 0.25),
                (80,  80,  [3, 5, 7, 9], [1, 1], [1, 1], 1, 6, 'Swish', 0.25),
                (80,  80,  [3, 5, 7, 9], [1, 1], [1, 1], 1, 6, 'Swish', 0.25),
                (80,  80,  [3, 5, 7, 9], [1, 1], [1, 1], 1, 6, 'Swish', 0.25),
                (80,  120, [3],          [1],    [1],    1, 6, 'Swish', 0.5),
                (120, 120, [3, 5, 7, 9], [1, 1], [1, 1], 1, 3, 'Swish', 0.5),
                (120, 120, [3, 5, 7, 9], [1, 1], [1, 1], 1, 3, 'Swish', 0.5),
                (120, 120, [3, 5, 7, 9], [1, 1], [1, 1], 1, 3, 'Swish', 0.5),
                (120, 200, [3, 5, 7, 9], [1],    [1], 2, 6, 'Swish', 0.5),
                (200, 200, [3, 5, 7, 9], [1],    [1, 1], 1, 6, 'Swish', 0.5),
                (200, 200, [3, 5, 7, 9], [1],    [1, 1], 1, 6, 'Swish', 0.5),
                (200, 200, [3, 5, 7, 9], [1],    [1, 1], 1, 6, 'Swish', 0.5)]

    def __init__(self, net_type='mixnet_m', input_size=224, num_classes=400, stem_channels=16, feature_size=1536, depth_multiplier=1.0):
        super(MixNet, self).__init__()

        if net_type == 'mixnet_s':
            config = self.mixnet_s
            stem_channels = 16
            dropout_rate = 0.2
        elif net_type == 'mixnet_m':
            config = self.mixnet_m
            stem_channels = 24
            dropout_rate = 0.25
        elif net_type == 'mixnet_l':
            config = self.mixnet_m
            stem_channels = 24
            depth_multiplier *= 1.12
            dropout_rate = 0.25
        else:
            raise TypeError('Unsupported MixNet type')

        assert input_size % 32 == 0

        # depth multiplier
        if depth_multiplier != 1.0:
            stem_channels = _RoundChannels(stem_channels*depth_multiplier)

            for i, conf in enumerate(config):
                conf_ls = list(conf)
                conf_ls[0] = _RoundChannels(conf_ls[0]*depth_multiplier)
                conf_ls[1] = _RoundChannels(conf_ls[1]*depth_multiplier)
                config[i] = tuple(conf_ls)

        # stem convolution
        self.stem_conv = Conv3x3Bn(3, stem_channels, 2)

        # building MixNet blocks
        layers = []
        for in_channels, out_channels, kernel_size, expand_ksize, project_ksize, stride, expand_ratio, non_linear, se_ratio in config:
            layers.append(MixNetBlock(
                in_channels,
                out_channels,
                kernel_size=kernel_size,
                expand_ksize=expand_ksize,
                project_ksize=project_ksize,
                stride=stride,
                expand_ratio=expand_ratio,
                non_linear=non_linear,
                se_ratio=se_ratio
            ))
        self.layers = nn.Sequential(*layers)

        # last several layers
        self.head_conv = Conv1x1Bn(config[-1][1], feature_size)

        self.avgpool = nn.AvgPool2d(input_size//32, stride=1)
        self.dropout = nn.Dropout(dropout_rate)
        self.classifier = nn.Linear(feature_size, num_classes)

        self._initialize_weights()

    def forward(self, x):
        x = self.stem_conv(x)
        x = self.layers(x)
        x = self.head_conv(x)
        x = self.avgpool(x)
        x = x.view(x.size(0), -1)
        x = self.dropout(x)
        x = self.classifier(x)

        return x

    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                m.weight.data.normal_(0, math.sqrt(2.0 / n))
                if m.bias is not None:
                    m.bias.data.zero_()
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()
            elif isinstance(m, nn.Linear):
                n = m.weight.size(1)
                m.weight.data.normal_(0, 0.01)
                m.bias.data.zero_()


# if __name__ == '__main__':
#     net = MixNet()
#     x_image = Variable(torch.randn(1, 3, 224, 224))
#     y = net(x_image)

# %% [markdown]
# Parameter가 5M 미만이 되도록 Custom한 ResNet 코드입니다.
# 다른 Model을 사용하는 경우 삭제해도 무방합니다.

# %% [markdown]
# 위에서 정의한 Model을 만들고 Parameter수를 체크한 후
# 5M 미만인 경우 GPU에서 정상 사용되는지 확인하는 부분입니다.

# %%
## 다시 돌릴때 해당 코드 돌려서 model 값 초기화해야한다!!!
# loading the model architecture
#model = ResNet44(num_classes).cuda()
model = MixNet()
# Check number of parameters your model
pytorch_total_params = sum(p.numel() for p in model.parameters())
print(f"Number of parameters: {pytorch_total_params}")
if int(pytorch_total_params) > 5000000:
    print('Your model has the number of parameters more than 5 millions..')
    sys.exit()
    
device = torch.device('cuda:0' if cuda.is_available() else 'cpu')
model.to(device)
print(device)
# Out:
# Number of parameters: 4092182
# cuda:0

# %% [markdown]
# Train Data를 불러와 Train set/Validation set으로 구분한 후
# 각 Data에 Augmentation 기법을 적용하는 부분입니다.

# %%
import torch
import math
import torch.nn.functional as F

from math import pi, cos, log, floor
from torch.optim.lr_scheduler import _LRScheduler

import math
from torch.optim.lr_scheduler import _LRScheduler

class CosineAnnealingWarmUpRestarts(_LRScheduler):
    def __init__(self, optimizer, T_0, T_mult=1, eta_max=0.1, T_up=0, gamma=1., last_epoch=-1):
        if T_0 <= 0 or not isinstance(T_0, int):
            raise ValueError("Expected positive integer T_0, but got {}".format(T_0))
        if T_mult < 1 or not isinstance(T_mult, int):
            raise ValueError("Expected integer T_mult >= 1, but got {}".format(T_mult))
        if T_up < 0 or not isinstance(T_up, int):
            raise ValueError("Expected positive integer T_up, but got {}".format(T_up))
        self.T_0 = T_0
        self.T_mult = T_mult
        self.base_eta_max = eta_max
        self.eta_max = eta_max
        self.T_up = T_up
        self.T_i = T_0
        self.gamma = gamma
        self.cycle = 0
        self.T_cur = last_epoch
        super(CosineAnnealingWarmUpRestarts, self).__init__(optimizer, last_epoch)
    
    def get_lr(self):
        if self.T_cur == -1:
            return self.base_lrs
        elif self.T_cur < self.T_up:
            return [(self.eta_max - base_lr)*self.T_cur / self.T_up + base_lr for base_lr in self.base_lrs]
        else:
            return [base_lr + (self.eta_max - base_lr) * (1 + math.cos(math.pi * (self.T_cur-self.T_up) / (self.T_i - self.T_up))) / 2
                    for base_lr in self.base_lrs]

    def step(self, epoch=None):
        if epoch is None:
            epoch = self.last_epoch + 1
            self.T_cur = self.T_cur + 1
            if self.T_cur >= self.T_i:
                self.cycle += 1
                self.T_cur = self.T_cur - self.T_i
                self.T_i = (self.T_i - self.T_up) * self.T_mult + self.T_up
        else:
            if epoch >= self.T_0:
                if self.T_mult == 1:
                    self.T_cur = epoch % self.T_0
                    self.cycle = epoch // self.T_0
                else:
                    n = int(math.log((epoch / self.T_0 * (self.T_mult - 1) + 1), self.T_mult))
                    self.cycle = n
                    self.T_cur = epoch - self.T_0 * (self.T_mult ** n - 1) / (self.T_mult - 1)
                    self.T_i = self.T_0 * self.T_mult ** (n)
            else:
                self.T_i = self.T_0
                self.T_cur = epoch
                
        self.eta_max = self.base_eta_max * (self.gamma**self.cycle)
        self.last_epoch = math.floor(epoch)
        for param_group, lr in zip(self.optimizer.param_groups, self.get_lr()):
            param_group['lr'] = lr
            
class LabelSmoothingCrossEntropy(nn.Module):
    def __init__(self):
        super(LabelSmoothingCrossEntropy, self).__init__()
    def forward(self, x, target, smoothing=0.1):
        confidence = 1. - smoothing
        logprobs = F.log_softmax(x, dim=-1)
        nll_loss = -logprobs.gather(dim=-1, index=target.unsqueeze(1))
        nll_loss = nll_loss.squeeze(1)
        smooth_loss = -logprobs.mean(dim=-1)
        loss = confidence * nll_loss + smoothing * smooth_loss
        return loss.mean()

class SAM(torch.optim.Optimizer):
    def __init__(self, params, base_optimizer, rho=0.05, **kwargs):
        assert rho >= 0.0, f"Invalid rho, should be non-negative: {rho}"

        defaults = dict(rho=rho, **kwargs)
        super(SAM, self).__init__(params, defaults)

        self.base_optimizer = base_optimizer(self.param_groups, **kwargs)
        self.param_groups = self.base_optimizer.param_groups

    @torch.no_grad()
    def first_step(self, zero_grad=False):
        grad_norm = self._grad_norm()
        for group in self.param_groups:
            scale = group["rho"] / (grad_norm + 1e-12)

            for p in group["params"]:
                if p.grad is None: continue
                e_w = p.grad * scale
                p.add_(e_w)  # climb to the local maximum "w + e(w)"
                self.state[p]["e_w"] = e_w

        if zero_grad: self.zero_grad()

    @torch.no_grad()
    def second_step(self, zero_grad=False):
        for group in self.param_groups:
            for p in group["params"]:
                if p.grad is None: continue
                p.sub_(self.state[p]["e_w"])  # get back to "w" from "w + e(w)"

        self.base_optimizer.step()  # do the actual "sharpness-aware" update

        if zero_grad: self.zero_grad()

    def step(self, closure=None):
        raise NotImplementedError("SAM doesn't work like the other optimizers, you should first call `first_step` and the `second_step`; see the documentation for more info.")

    def _grad_norm(self):
        norm = torch.norm(
                    torch.stack([
                        p.grad.norm(p=2)
                        for group in self.param_groups for p in group["params"]
                        if p.grad is not None
                    ]),
                    p=2
               )
        return norm

class SAM(torch.optim.Optimizer):
    def __init__(self, params, base_optimizer, rho=0.05, adaptive=False, **kwargs):
        assert rho >= 0.0, f"Invalid rho, should be non-negative: {rho}"

        defaults = dict(rho=rho, adaptive=adaptive, **kwargs)
        super(SAM, self).__init__(params, defaults)

        self.base_optimizer = base_optimizer(self.param_groups, **kwargs)
        self.param_groups = self.base_optimizer.param_groups

    @torch.no_grad()
    def first_step(self, zero_grad=False):
        grad_norm = self._grad_norm()
        for group in self.param_groups:
            scale = group["rho"] / (grad_norm + 1e-12)

            for p in group["params"]:
                if p.grad is None: continue
                self.state[p]["old_p"] = p.data.clone()
                e_w = (torch.pow(p, 2) if group["adaptive"] else 1.0) * p.grad * scale.to(p)
                p.add_(e_w)  # climb to the local maximum "w + e(w)"

        if zero_grad: self.zero_grad()

    @torch.no_grad()
    def second_step(self, zero_grad=False):
        for group in self.param_groups:
            for p in group["params"]:
                if p.grad is None: continue
                p.data = self.state[p]["old_p"]  # get back to "w" from "w + e(w)"

        self.base_optimizer.step()  # do the actual "sharpness-aware" update

        if zero_grad: self.zero_grad()

    @torch.no_grad()
    def step(self, closure=None):
        assert closure is not None, "Sharpness Aware Minimization requires closure, but it was not provided"
        closure = torch.enable_grad()(closure)  # the closure should do a full forward-backward pass

        self.first_step(zero_grad=True)
        closure()
        self.second_step()

    def _grad_norm(self):
        shared_device = self.param_groups[0]["params"][0].device  # put everything on the same device, in case of model parallelism
        norm = torch.norm(
                    torch.stack([
                        ((torch.abs(p) if group["adaptive"] else 1.0) * p.grad).norm(p=2).to(shared_device)
                        for group in self.param_groups for p in group["params"]
                        if p.grad is not None
                    ]),
                    p=2
               )
        return norm

    def load_state_dict(self, state_dict):
        super().load_state_dict(state_dict)
        self.base_optimizer.param_groups = self.param_groups

# %%
#doing data augmentation 
train_transform = transforms.Compose([
        transforms.Resize(224),
        transforms.RandomCrop(224, padding = 16),
        transforms.RandomRotation((-8,8)),
        transforms.RandomChoice([
            transforms.RandomHorizontalFlip(),
            transforms.RandomVerticalFlip(),
        ]),
        transforms.ToTensor(),
        transforms.RandomErasing(),
        transforms.Normalize([0.4704, 0.4669, 0.3898], [0.2392, 0.2329, 0.2546])
    ])
# val_transform = transforms.Compose([
#         transforms.Resize(224),
#         # #transforms.RandomCrop(224, padding = 20),
#         # transforms.RandomRotation((-8,8)),
#         # transforms.RandomChoice([
#         #     transforms.RandomHorizontalFlip(),
#         #     transforms.RandomVerticalFlip(),
#         # ]),
#         transforms.ToTensor(),
#         # transforms.RandomErasing(),
#         transforms.Normalize([0.4704, 0.4669, 0.3898], [0.2392, 0.2329, 0.2546])
#     ])
# train_transform = transforms.Compose([transforms.Resize((64,64)),transforms.RandomRotation(45),transforms.RandomHorizontalFlip(),
#                                       transforms.RandomVerticalFlip(),transforms.ToTensor(),
#                                       transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])])
# val_transform = transforms.Compose([transforms.Resize((64,64)),transforms.RandomRotation(45),transforms.RandomHorizontalFlip(),
#                                     transforms.RandomVerticalFlip(),transforms.ToTensor(),
#                                     transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])])

# %%
# splitting the data into train/validation/test sets
data = datasets.ImageFolder(data_dir)
# train_size = int(len(data)*0.9)
# val_size = int((len(data)-train_size))
#train_data,val_data = random_split(data,[train_size,val_size])
torch.manual_seed(3334)
torch.cuda.manual_seed(3334)
#print(f'train size: {len(train_data)}\nval size: {len(val_data)}')
 
#train_data.dataset.transform = train_transform
#val_data.dataset.transform = val_transform
data.transform = train_transform
batch_size = 128
train_loader = DataLoader(data,batch_size=batch_size,shuffle=True)

#train_loader = DataLoader(train_data,batch_size=batch_size,shuffle=True)
#val_loader = DataLoader(val_data,batch_size=batch_size,shuffle=True)

# %% [markdown]
# Loss Function과 Optimizer를 선언하는 부분입니다.
# 다양한 Loss와 Optimizer를 통해 성능을 올려보세요!

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.0001, momentum=0.9, nesterov=True, weight_decay=5e-4)
#optimizer = torch.optim.Adam(model.parameters(), lr=1e-4, weight_decay=5e-4)
SAVEPATH = '/content/drive/MyDrive/model_output'
scheduler = CosineAnnealingWarmUpRestarts(optimizer, T_0=50, T_mult=1, eta_max=0.1, T_up=10)

# %% [markdown]
# Train 해주는 함수입니다.

# %%
def fit(model,criterion,optimizer,num_epochs=10):
    print_freq = 30
    start = time.time()
    best_model = model.state_dict()
    best_acc = 0
    train_loss_over_time = []

    train_acc_over_time = []



    # each epoch has a training and validation phase
    for epoch in range(num_epochs):
        
        print("\n----- epoch: {}, lr: {} -----".format(epoch, optimizer.param_groups[0]["lr"]))
        batch_time = AverageMeter('Time', ':6.3f')
        acc = AverageMeter('Accuracy', ':.4e')
        progress = ProgressMeter(len(train_loader), batch_time, acc, prefix="Epoch: [{}]".format(epoch))


            

        data_loader = train_loader
        model.train()                    # set the model to train mode
        end = time.time()

        
            
        running_loss = 0.0
        running_corrects = 0.0
        
        # iterate over the data
        for i,(inputs,labels) in enumerate(data_loader):
            inputs = inputs.to(device)
            labels = labels.to(device)
            
            # zero the parameter gradients
            optimizer.zero_grad()
            
            # forward
            with torch.set_grad_enabled(True):
                outputs = model(inputs)
                _,pred = torch.max(outputs,dim=1)
                loss = criterion(outputs,labels)
                
                # backward + optimize only if in training phase

                loss.backward()
                optimizer.step()
            
            # calculating the loss and accuracy
            running_loss += loss.item() * inputs.size(0)
            running_corrects += torch.sum(pred == labels.data)

            epoch_acc = (running_corrects.double()/len(data)).cpu().numpy()
            acc.update(epoch_acc.item(), inputs.size(0))
            
                          
            batch_time.update(time.time() - end)
            end = time.time()

            if i % print_freq == 0:
                progress.print(i)  



        epoch_loss = running_loss/len(data)
        train_loss_over_time.append(epoch_loss)
        epoch_acc = (running_corrects.double()/len(data)).cpu().numpy()
        train_acc_over_time.append(epoch_acc)


        

        print(f'loss: {epoch_loss:.3f}, acc: {epoch_acc:.3f}')

        scheduler.step()
        torch.save(model.state_dict(),SAVEPATH+'/model_all_train_mix_final.pt')
        

    print('-'*60)
    print('\n') 
    elapsed_time = time.time() - start
    print('==> {:.2f} seconds to train this epoch\n'.format(elapsed_time))
    print(f'best accuracy: {best_acc:.3f}')


    # load best model weights
    model.load_state_dict(best_model)
    loss = {'train':train_loss_over_time}
    acc = {'train':train_acc_over_time}

    return model,loss, acc

# %% [markdown]
# Train 함수를 통해 Epoch수만큼 학습하는 부분입니다.

# %%
# training the model
# trained for 5 epochs then for 3 epochs then 2
import gc
gc.collect()
torch.cuda.empty_cache()
epochs = 50
history, loss, acc = fit(model, criterion, optimizer, num_epochs = epochs)
# Out:
# ----- epoch: 0, lr: 0.0001 -----
# Epoch: [0][  0/457]	Time  1.441 ( 1.441)	Accuracy 0.0000e+00 (0.0000e+00)
# Epoch: [0][ 30/457]	Time  1.079 ( 1.091)	Accuracy 8.5634e-05 (2.6519e-05)
# Epoch: [0][ 60/457]	Time  1.085 ( 1.084)	Accuracy 2.2265e-04 (9.5742e-05)
# Epoch: [0][ 90/457]	Time  1.069 ( 1.081)	Accuracy 3.7679e-04 (1.6412e-04)
# Epoch: [0][120/457]	Time  1.073 ( 1.079)	Accuracy 5.3093e-04 (2.3850e-04)
# Epoch: [0][150/457]	Time  1.070 ( 1.081)	Accuracy 7.1933e-04 (3.2008e-04)
# Epoch: [0][180/457]	Time  1.086 ( 1.080)	Accuracy 8.7347e-04 (4.0111e-04)
# Epoch: [0][210/457]	Time  1.075 ( 1.079)	Accuracy 1.1132e-03 (4.8345e-04)
# Epoch: [0][240/457]	Time  1.060 ( 1.078)	Accuracy 1.3016e-03 (5.7250e-04)
# Epoch: [0][270/457]	Time  1.073 ( 1.077)	Accuracy 1.5414e-03 (6.6384e-04)
# Epoch: [0][300/457]	Time  1.064 ( 1.077)	Accuracy 1.7127e-03 (7.6098e-04)
# Epoch: [0][330/457]	Time  1.080 ( 1.077)	Accuracy 1.8839e-03 (8.5551e-04)
# Epoch: [0][360/457]	Time  1.069 ( 1.077)	Accuracy 2.0552e-03 (9.4715e-04)
# Epoch: [0][390/457]	Time  1.062 ( 1.078)	Accuracy 2.2094e-03 (1.0383e-03)
# Epoch: [0][420/457]	Time  1.066 ( 1.078)	Accuracy 2.4663e-03 (1.1300e-03)
# Epoch: [0][450/457]	Time  1.068 ( 1.077)	Accuracy 2.7232e-03 (1.2285e-03)
# loss: 6.076, acc: 0.003
#
# ----- epoch: 1, lr: 0.01009 -----
# Epoch: [1][  0/457]	Time  1.103 ( 1.103)	Accuracy 0.0000e+00 (0.0000e+00)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-fad142d734a8> in <module>()
#       5 torch.cuda.empty_cache()
#       6 epochs = 50
# ----> 7 history, loss, acc = fit(model, criterion, optimizer, num_epochs = epochs)
#
# <ipython-input-18-81c4ea100bfc> in fit(model, criterion, optimizer, num_epochs)
#      31
#      32         # iterate over the data
# ---> 33         for i,(inputs,labels) in enumerate(data_loader):
#      34             inputs = inputs.to(device)
#      35             labels = labels.to(device)
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     528             if self._sampler_iter is None:
#     529                 self._reset()
# --> 530             data = self._next_data()
#     531             self._num_yielded += 1
#     532             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     568     def _next_data(self):
#     569         index = self._next_index()  # may raise StopIteration
# --> 570         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     571         if self._pin_memory:
#     572             data = _utils.pin_memory.pin_memory(data)
#
# KeyboardInterrupt:

# %% [markdown]
# Test Dataset을 불러오는 부분입니다.

# %%
seed = 0
torch.manual_seed(seed)
if cuda:
    torch.cuda.manual_seed(seed)

torch.manual_seed(3334)
test_transform = transforms.Compose([transforms.Resize((224)),transforms.ToTensor(),
                                    transforms.Normalize([0.4704, 0.4669, 0.3898], [0.2392, 0.2329, 0.2546])])

# splitting the data into train/validation/test sets
test_data_dir = '/content/dataset/test'
_data = datasets.ImageFolder(test_data_dir)
test1_size = int(len(_data)*1)
test2_size = int((len(_data)-test1_size))
test_data, test2_data = torch.utils.data.random_split(_data,[test1_size, test2_size])
torch.manual_seed(3334)

print(f'test size: {len(test_data)}')

test_data.dataset.transform = test_transform
batch_size = 128
test_loader = DataLoader(test_data, batch_size = batch_size, shuffle = False)
print(test_loader)
# Out:
# test size: 2000
# <torch.utils.data.dataloader.DataLoader object at 0x7f8a681b3c10>

# %% [markdown]
# 앞에서 훈련 시킨 Model중 가장 높은 정확도를 가진 모델을 불러와 Test Dataset에 대한 결과를 만들어주는 부분으로 이 코드는 변경하지 않아도 됩니다.

# %%
import itertools
# testing how good the model is
def evaluate(model,criterion):
    model.eval()       # setting the model to evaluate mode
    preds = []
    Category = []

    #test_model = ResNet34(num_classes=400).cuda()
    test_model = model
    #저장경로는 변경하셔도 됩니다.
    test_model.load_state_dict(torch.load('/content/drive/MyDrive/model_output/model_all_train_mix_final.pt'))
    #top1 = AverageMeter('Acc@1', ':6.2f')

    for inputs, label_ in test_loader:
        
        inputs = inputs.to(device)
        labels = label_.to(device)
        # predicting
        with torch.no_grad():

            outputs = test_model(inputs)
            _,pred = torch.max(outputs,dim=1)
            acc1 = accuracy(outputs, labels, topk=(1,))
            #top1.update(acc1[0].item(), inputs.size(0))
            preds.append(pred)

    category = [t.cpu().numpy() for t in preds]
    
    t_category = list(itertools.chain(*category))
   
    Id = list(range(0, len(t_category)))

    prediction = {
      'Id': Id,
      'Category': t_category 
    }

    prediction_df = pd.DataFrame(prediction, columns=['Id','Category'])
    #저장경로는 변경하셔도 됩니다.
    prediction_df.to_csv('/content/drive/MyDrive/prediction.csv', index=False)
    #print(top1)
    #print(top1.avg)
    print('Done!!')
        
    return preds

# testing the model
predictions = evaluate(model, criterion)
# Out:
# Done!!
